# %% [markdown]
# # Basket Preparation
#
# # 2
#
# # Mục tiêu:
# # - Biến dữ liệu giao dịch thành dạng basket boolean
# # - Chuẩn bị đầu vào cho Apriori & FP-Growth

# %%
import pandas as pd
from src.apriori_library import BasketPreparer

df = pd.read_csv("../data/processed/cleaned_uk_data.csv")

# %%
preparer = BasketPreparer(min_item_freq=50)
basket_bool = preparer.prepare_basket(df)

basket_bool.head()

# %%
basket_bool.to_parquet("../data/processed/basket_bool.parquet")
